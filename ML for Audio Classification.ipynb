# %%
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa.display
from scipy.io import wavfile as wav
# %matplotlib inline
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ### Understanding Metadata

# %%
#loading maadata from csv file 
metadata = pd.read_csv('Audio_Data/BG_BR.csv')

#printing metadata 
metadata.head()
# Out:
#                          slice_file_name    FSID  Maximum_Amplitude  \
# 0  Ball_Bounce_On_Ground.wav001_user.wav  211213           0.608783
# 1  Ball_Bounce_On_Ground.wav002_user.wav  211213           0.688888
# 2  Ball_Bounce_On_Ground.wav003_user.wav  211213           0.669433
# 3  Ball_Bounce_On_Ground.wav004_user.wav  211213           0.597916
# 4  Ball_Bounce_On_Ground.wav005_user.wav  211213           0.552153
#
#    Minimum_Amplitude Start Time in original File(Sec)  \
# 0          -0.274387                   [[4.65487528]]
# 1          -0.962503      [[ 21.5752381 404.8645805]]
# 2          -0.694868                   [[23.8215873]]
# 3          -0.766195                  [[24.99750567]]
# 4          -0.623119                  [[30.62698413]]
#
#   End Time in orignal File(Sec)  Class ID  fold            class  \
# 0                [[4.95482993]]         2     1  Ball Ground Hit
# 1               [[21.87519274]]         2     1  Ball Ground Hit
# 2               [[24.12154195]]         2     1  Ball Ground Hit
# 3               [[25.29746032]]         2     1  Ball Ground Hit
# 4               [[30.92693878]]         2     1  Ball Ground Hit
#
#                                    Location on drive
# 0  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 1  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 2  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 3  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 4  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...

# %%
#check for imbalance dataset
#if the difference in numbers of files is significant then our data will be consider as imbalanced data
metadata['class'].value_counts()
# Out:
# Ball Ground Hit    754
# Ball Racket Hit    694
# Name: class, dtype: int64

# %% [markdown]
# ### Data Preprocessing

# %%
#loading csv file 
audio_dataset_path = 'Audio_Data/Audio/'
metadata=pd.read_csv('Audio_Data/BG_BR.csv')
#printing metadata 
metadata.head()
# Out:
#                          slice_file_name    FSID  Maximum_Amplitude  \
# 0  Ball_Bounce_On_Ground.wav001_user.wav  211213           0.608783
# 1  Ball_Bounce_On_Ground.wav002_user.wav  211213           0.688888
# 2  Ball_Bounce_On_Ground.wav003_user.wav  211213           0.669433
# 3  Ball_Bounce_On_Ground.wav004_user.wav  211213           0.597916
# 4  Ball_Bounce_On_Ground.wav005_user.wav  211213           0.552153
#
#    Minimum_Amplitude Start Time in original File(Sec)  \
# 0          -0.274387                   [[4.65487528]]
# 1          -0.962503      [[ 21.5752381 404.8645805]]
# 2          -0.694868                   [[23.8215873]]
# 3          -0.766195                  [[24.99750567]]
# 4          -0.623119                  [[30.62698413]]
#
#   End Time in orignal File(Sec)  Class ID  fold            class  \
# 0                [[4.95482993]]         2     1  Ball Ground Hit
# 1               [[21.87519274]]         2     1  Ball Ground Hit
# 2               [[24.12154195]]         2     1  Ball Ground Hit
# 3               [[25.29746032]]         2     1  Ball Ground Hit
# 4               [[30.92693878]]         2     1  Ball Ground Hit
#
#                                    Location on drive
# 0  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 1  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 2  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 3  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...
# 4  C:/Users/Ankit Kumar/Audio_Data/BallBounceOnGr...

# %%
#the mel-frequency cepstrum (MFC) is a representation of the short-term power spectrum of a sound, based on a linear cosine transform of a log power spectrum on a nonlinear mel scale of frequency.
# n_mfcc = number of MFCCs to return
#sr = sample rate, y =audio time series

def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate,n_mfcc = 40)
    mfccs_scaled_features=np.mean(mfccs_features.T, axis=0)
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
### Now we iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),'fold'+str(row["fold"])+'\\',str(row["slice_file_name"]))
    final_class_labels=row["class"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 1448it [00:07, 199.40it/s]

# %%
#creating dataframe  from the list of etracted features
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])

# %%
#printing dataframe and saving it into csv for better understanding
extracted_features_df.head()
# Out:
#                                              feature            class
# 0  [-218.40462, 153.12389, -25.449078, 22.280703,...  Ball Ground Hit
# 1  [-252.92578, 142.6328, -23.307566, 17.159676, ...  Ball Ground Hit
# 2  [-270.47318, 151.5141, -31.51296, 22.09384, 13...  Ball Ground Hit
# 3  [-263.1113, 145.61594, -30.467701, 20.84265, 1...  Ball Ground Hit
# 4  [-270.6276, 146.31517, -32.099884, 19.047443, ...  Ball Ground Hit

# %%
### Split the dataset into independent and dependent dataset
X=np.array(extracted_features_df['feature'].tolist())

# %%
### Split the dataset into independent and dependent dataset
y = np.array(extracted_features_df['class'].tolist())

# %%
#Label Encoding refers to converting the labels into numeric form so as to convert it into the machine-readable form. 
y=np.array(pd.get_dummies(y))

# %%
#spliting dataset into test and train data
#random state = 0 (random datasets would be taken each time we will run the program)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
#obtaining the shape of test and train datasets
X_train.shape
X_test.shape
y_train.shape
y_test.shape
print('X_shape: ',X_train.shape)
print('X_test: ',X_test.shape)
print('y_train: ',y_train.shape)
print('y_test: ',y_test.shape)
#print(No of training dataset or testing data set,no of features or labels)
# Out:
# X_shape:  (1158, 40)
# X_test:  (290, 40)
# y_train:  (1158, 2)
# y_test:  (290, 2)

# %% [markdown]
# ## Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
num_labels=y.shape[1]
num_labels
# Out:
# 2

# %%
#Creating model
#here we have used 100,200,100 nurons in different layers
#we have use relu activation function
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))

###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
#model summary for better understanding
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_32 (Dense)             (None, 100)               4100
# _________________________________________________________________
# activation_32 (Activation)   (None, 100)               0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 200)               20200
# _________________________________________________________________
# activation_33 (Activation)   (None, 200)               0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 100)               20100
# _________________________________________________________________
# activation_34 (Activation)   (None, 100)               0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 2)                 202
# _________________________________________________________________
# activation_35 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 44,602
# Trainable params: 44,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
#selecting loss function adn optimizer
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
## Trianing the model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 40

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 1s 15ms/step - loss: 12.0405 - accuracy: 0.5751 - val_loss: 0.1400 - val_accuracy: 0.9690
#
# Epoch 00001: val_loss improved from inf to 0.13997, saving model to saved_models\audio_classification.hdf5
# Epoch 2/100
# 29/29 [==============================] - 0s 5ms/step - loss: 4.8676 - accuracy: 0.6762 - val_loss: 0.2803 - val_accuracy: 0.9103
#
# Epoch 00002: val_loss did not improve from 0.13997
# Epoch 3/100
# 29/29 [==============================] - 0s 9ms/step - loss: 2.0812 - accuracy: 0.7608 - val_loss: 0.1444 - val_accuracy: 0.9586
#
# Epoch 00003: val_loss did not improve from 0.13997
# Epoch 4/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0622 - accuracy: 0.8575 - val_loss: 0.1315 - val_accuracy: 0.9690
#
# Epoch 00004: val_loss improved from 0.13997 to 0.13148, saving model to saved_models\audio_classification.hdf5
# Epoch 5/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5824 - accuracy: 0.9050 - val_loss: 0.1129 - val_accuracy: 0.9793
#
# Epoch 00005: val_loss improved from 0.13148 to 0.11287, saving model to saved_models\audio_classification.hdf5
# Epoch 6/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5014 - accuracy: 0.9111 - val_loss: 0.1117 - val_accuracy: 0.9828
#
# Epoch 00006: val_loss improved from 0.11287 to 0.11170, saving model to saved_models\audio_classification.hdf5
# Epoch 7/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3136 - accuracy: 0.9387 - val_loss: 0.1074 - val_accuracy: 0.9828
#
# Epoch 00007: val_loss improved from 0.11170 to 0.10739, saving model to saved_models\audio_classification.hdf5
# Epoch 8/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2777 - accuracy: 0.9413 - val_loss: 0.1048 - val_accuracy: 0.9828
#
# Epoch 00008: val_loss improved from 0.10739 to 0.10478, saving model to saved_models\audio_classification.hdf5
# Epoch 9/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1708 - accuracy: 0.9663 - val_loss: 0.1042 - val_accuracy: 0.9828
#
# Epoch 00009: val_loss improved from 0.10478 to 0.10422, saving model to saved_models\audio_classification.hdf5
# Epoch 10/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1482 - accuracy: 0.9741 - val_loss: 0.1016 - val_accuracy: 0.9862
#
# Epoch 00010: val_loss improved from 0.10422 to 0.10161, saving model to saved_models\audio_classification.hdf5
# Epoch 11/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1318 - accuracy: 0.9724 - val_loss: 0.1175 - val_accuracy: 0.9897
#
# Epoch 00011: val_loss did not improve from 0.10161
# Epoch 12/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1235 - accuracy: 0.9810 - val_loss: 0.1007 - val_accuracy: 0.9897
#
# Epoch 00012: val_loss improved from 0.10161 to 0.10068, saving model to saved_models\audio_classification.hdf5
# Epoch 13/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9810 - val_loss: 0.0966 - val_accuracy: 0.9862
#
# Epoch 00013: val_loss improved from 0.10068 to 0.09661, saving model to saved_models\audio_classification.hdf5
# Epoch 14/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9767 - val_loss: 0.0982 - val_accuracy: 0.9897
#
# Epoch 00014: val_loss did not improve from 0.09661
# Epoch 15/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9879 - val_loss: 0.0882 - val_accuracy: 0.9862
#
# Epoch 00015: val_loss improved from 0.09661 to 0.08821, saving model to saved_models\audio_classification.hdf5
# Epoch 16/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0679 - accuracy: 0.9836 - val_loss: 0.0952 - val_accuracy: 0.9931
#
# Epoch 00016: val_loss did not improve from 0.08821
# Epoch 17/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9810 - val_loss: 0.0913 - val_accuracy: 0.9931
#
# Epoch 00017: val_loss did not improve from 0.08821
# Epoch 18/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9879 - val_loss: 0.0829 - val_accuracy: 0.9897
#
# Epoch 00018: val_loss improved from 0.08821 to 0.08291, saving model to saved_models\audio_classification.hdf5
# Epoch 19/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0877 - accuracy: 0.9810 - val_loss: 0.0784 - val_accuracy: 0.9897
#
# Epoch 00019: val_loss improved from 0.08291 to 0.07843, saving model to saved_models\audio_classification.hdf5
# Epoch 20/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0369 - accuracy: 0.9940 - val_loss: 0.0799 - val_accuracy: 0.9931
#
# Epoch 00020: val_loss did not improve from 0.07843
# Epoch 21/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0603 - accuracy: 0.9888 - val_loss: 0.0800 - val_accuracy: 0.9931
#
# Epoch 00021: val_loss did not improve from 0.07843
# Epoch 22/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0598 - accuracy: 0.9870 - val_loss: 0.0713 - val_accuracy: 0.9931
#
# Epoch 00022: val_loss improved from 0.07843 to 0.07128, saving model to saved_models\audio_classification.hdf5
# Epoch 23/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 0.9862 - val_loss: 0.0660 - val_accuracy: 0.9931
#
# Epoch 00023: val_loss improved from 0.07128 to 0.06596, saving model to saved_models\audio_classification.hdf5
# Epoch 24/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 0.9896 - val_loss: 0.0703 - val_accuracy: 0.9931
#
# Epoch 00024: val_loss did not improve from 0.06596
# Epoch 25/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0362 - accuracy: 0.9940 - val_loss: 0.0623 - val_accuracy: 0.9931
#
# Epoch 00025: val_loss improved from 0.06596 to 0.06230, saving model to saved_models\audio_classification.hdf5
# Epoch 26/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 0.9888 - val_loss: 0.0644 - val_accuracy: 0.9931
#
# Epoch 00026: val_loss did not improve from 0.06230
# Epoch 27/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9948 - val_loss: 0.0630 - val_accuracy: 0.9931
#
# Epoch 00027: val_loss did not improve from 0.06230
# Epoch 28/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0483 - accuracy: 0.9914 - val_loss: 0.0613 - val_accuracy: 0.9931
#
# Epoch 00028: val_loss improved from 0.06230 to 0.06126, saving model to saved_models\audio_classification.hdf5
# Epoch 29/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.9931 - val_loss: 0.0608 - val_accuracy: 0.9931
#
# Epoch 00029: val_loss improved from 0.06126 to 0.06082, saving model to saved_models\audio_classification.hdf5
# Epoch 30/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9957 - val_loss: 0.0546 - val_accuracy: 0.9966
#
# Epoch 00030: val_loss improved from 0.06082 to 0.05459, saving model to saved_models\audio_classification.hdf5
# Epoch 31/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 0.9922 - val_loss: 0.0536 - val_accuracy: 0.9931
#
# Epoch 00031: val_loss improved from 0.05459 to 0.05360, saving model to saved_models\audio_classification.hdf5
# Epoch 32/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9940 - val_loss: 0.0497 - val_accuracy: 0.9966
#
# Epoch 00032: val_loss improved from 0.05360 to 0.04969, saving model to saved_models\audio_classification.hdf5
# Epoch 33/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0372 - accuracy: 0.9931 - val_loss: 0.0547 - val_accuracy: 0.9966
#
# Epoch 00033: val_loss did not improve from 0.04969
# Epoch 34/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9948 - val_loss: 0.0548 - val_accuracy: 0.9966
#
# Epoch 00034: val_loss did not improve from 0.04969
# Epoch 35/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 0.9940 - val_loss: 0.0506 - val_accuracy: 0.9966
#
# Epoch 00035: val_loss did not improve from 0.04969
# Epoch 36/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0356 - accuracy: 0.9931 - val_loss: 0.0504 - val_accuracy: 0.9966
#
# Epoch 00036: val_loss did not improve from 0.04969
# Epoch 37/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9957 - val_loss: 0.0523 - val_accuracy: 0.9966
#
# Epoch 00037: val_loss did not improve from 0.04969
# Epoch 38/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9948 - val_loss: 0.0529 - val_accuracy: 0.9966
#
# Epoch 00038: val_loss did not improve from 0.04969
# Epoch 39/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 0.0536 - val_accuracy: 0.9966
#
# Epoch 00039: val_loss did not improve from 0.04969
# Epoch 40/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0337 - accuracy: 0.9931 - val_loss: 0.0451 - val_accuracy: 0.9966
#
# Epoch 00040: val_loss improved from 0.04969 to 0.04506, saving model to saved_models\audio_classification.hdf5
# Epoch 41/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9965 - val_loss: 0.0489 - val_accuracy: 0.9966
#
# Epoch 00041: val_loss did not improve from 0.04506
# Epoch 42/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9983 - val_loss: 0.0496 - val_accuracy: 0.9966
#
# Epoch 00042: val_loss did not improve from 0.04506
# Epoch 43/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9914 - val_loss: 0.0444 - val_accuracy: 0.9966
#
# Epoch 00043: val_loss improved from 0.04506 to 0.04438, saving model to saved_models\audio_classification.hdf5
# Epoch 44/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.0507 - val_accuracy: 0.9966
#
# Epoch 00044: val_loss did not improve from 0.04438
# Epoch 45/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9931 - val_loss: 0.0525 - val_accuracy: 0.9966
#
# Epoch 00045: val_loss did not improve from 0.04438
# Epoch 46/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9965 - val_loss: 0.0466 - val_accuracy: 0.9966
#
# Epoch 00046: val_loss did not improve from 0.04438
# Epoch 47/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.0436 - val_accuracy: 0.9966
#
# Epoch 00047: val_loss improved from 0.04438 to 0.04364, saving model to saved_models\audio_classification.hdf5
# Epoch 48/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0475 - val_accuracy: 0.9966
#
# Epoch 00048: val_loss did not improve from 0.04364
# Epoch 49/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9957 - val_loss: 0.0497 - val_accuracy: 0.9966
#
# Epoch 00049: val_loss did not improve from 0.04364
# Epoch 50/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9940 - val_loss: 0.0455 - val_accuracy: 0.9966
#
# Epoch 00050: val_loss did not improve from 0.04364
# Epoch 51/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0456 - val_accuracy: 0.9966
#
# Epoch 00051: val_loss did not improve from 0.04364
# Epoch 52/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0525 - val_accuracy: 0.9966
#
# Epoch 00052: val_loss did not improve from 0.04364
# Epoch 53/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0557 - val_accuracy: 0.9966
#
# Epoch 00053: val_loss did not improve from 0.04364
# Epoch 54/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9957 - val_loss: 0.0500 - val_accuracy: 0.9966
#
# Epoch 00054: val_loss did not improve from 0.04364
# Epoch 55/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9957 - val_loss: 0.0499 - val_accuracy: 0.9966
#
# Epoch 00055: val_loss did not improve from 0.04364
# Epoch 56/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9974 - val_loss: 0.0509 - val_accuracy: 0.9966
#
# Epoch 00056: val_loss did not improve from 0.04364
# Epoch 57/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9974 - val_loss: 0.0540 - val_accuracy: 0.9966
#
# Epoch 00057: val_loss did not improve from 0.04364
# Epoch 58/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0557 - val_accuracy: 0.9966
#
# Epoch 00058: val_loss did not improve from 0.04364
# Epoch 59/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9983 - val_loss: 0.0579 - val_accuracy: 0.9966
#
# Epoch 00059: val_loss did not improve from 0.04364
# Epoch 60/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0592 - val_accuracy: 0.9966
#
# Epoch 00060: val_loss did not improve from 0.04364
# Epoch 61/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 0.9983 - val_loss: 0.0532 - val_accuracy: 0.9966
#
# Epoch 00061: val_loss did not improve from 0.04364
# Epoch 62/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.0517 - val_accuracy: 0.9966
#
# Epoch 00062: val_loss did not improve from 0.04364
# Epoch 63/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0587 - val_accuracy: 0.9966
#
# Epoch 00063: val_loss did not improve from 0.04364
# Epoch 64/100
# 29/29 [==============================] - 0s 4ms/step - loss: 6.4764e-04 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9966
#
# Epoch 00064: val_loss did not improve from 0.04364
# Epoch 65/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.0581 - val_accuracy: 0.9966
#
# Epoch 00065: val_loss did not improve from 0.04364
# Epoch 66/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9983 - val_loss: 0.0578 - val_accuracy: 0.9966
#
# Epoch 00066: val_loss did not improve from 0.04364
# Epoch 67/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0565 - val_accuracy: 0.9966
#
# Epoch 00067: val_loss did not improve from 0.04364
# Epoch 68/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0547 - val_accuracy: 0.9966
#
# Epoch 00068: val_loss did not improve from 0.04364
# Epoch 69/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0496 - val_accuracy: 0.9966
#
# Epoch 00069: val_loss did not improve from 0.04364
# Epoch 70/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9974 - val_loss: 0.0527 - val_accuracy: 0.9966
#
# Epoch 00070: val_loss did not improve from 0.04364
# Epoch 71/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.0555 - val_accuracy: 0.9966
#
# Epoch 00071: val_loss did not improve from 0.04364
# Epoch 72/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9966
#
# Epoch 00072: val_loss did not improve from 0.04364
# Epoch 73/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0478 - val_accuracy: 0.9966
#
# Epoch 00073: val_loss did not improve from 0.04364
# Epoch 74/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9983 - val_loss: 0.0534 - val_accuracy: 0.9966
#
# Epoch 00074: val_loss did not improve from 0.04364
# Epoch 75/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0579 - val_accuracy: 0.9966
#
# Epoch 00075: val_loss did not improve from 0.04364
# Epoch 76/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0580 - val_accuracy: 0.9966
#
# Epoch 00076: val_loss did not improve from 0.04364
# Epoch 77/100
# 29/29 [==============================] - 0s 7ms/step - loss: 4.1708e-04 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 0.9966
#
# Epoch 00077: val_loss did not improve from 0.04364
# Epoch 78/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 0.0600 - val_accuracy: 0.9966
#
# Epoch 00078: val_loss did not improve from 0.04364
# Epoch 79/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9991 - val_loss: 0.0583 - val_accuracy: 0.9966
#
# Epoch 00079: val_loss did not improve from 0.04364
# Epoch 80/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.9983 - val_loss: 0.0649 - val_accuracy: 0.9966
#
# Epoch 00080: val_loss did not improve from 0.04364
# Epoch 81/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0610 - val_accuracy: 0.9966
#
# Epoch 00081: val_loss did not improve from 0.04364
# Epoch 82/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9991 - val_loss: 0.0646 - val_accuracy: 0.9966
#
# Epoch 00082: val_loss did not improve from 0.04364
# Epoch 83/100
# 29/29 [==============================] - 0s 9ms/step - loss: 4.9575e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9966
#
# Epoch 00083: val_loss did not improve from 0.04364
# Epoch 84/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 0.9965 - val_loss: 0.0588 - val_accuracy: 0.9966
#
# Epoch 00084: val_loss did not improve from 0.04364
# Epoch 85/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.0677 - val_accuracy: 0.9966
#
# Epoch 00085: val_loss did not improve from 0.04364
# Epoch 86/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.2433e-04 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9966
#
# Epoch 00086: val_loss did not improve from 0.04364
# Epoch 87/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0695 - val_accuracy: 0.9966
#
# Epoch 00087: val_loss did not improve from 0.04364
# Epoch 88/100
# 29/29 [==============================] - 0s 4ms/step - loss: 5.7993e-04 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9966
#
# Epoch 00088: val_loss did not improve from 0.04364
# Epoch 89/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0704 - val_accuracy: 0.9966
#
# Epoch 00089: val_loss did not improve from 0.04364
# Epoch 90/100
# 29/29 [==============================] - 0s 4ms/step - loss: 5.7938e-04 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9966
#
# Epoch 00090: val_loss did not improve from 0.04364
# Epoch 91/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0712 - val_accuracy: 0.9966
#
# Epoch 00091: val_loss did not improve from 0.04364
# Epoch 92/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0631 - val_accuracy: 0.9966
#
# Epoch 00092: val_loss did not improve from 0.04364
# Epoch 93/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0644 - val_accuracy: 0.9966
#
# Epoch 00093: val_loss did not improve from 0.04364
# Epoch 94/100
# 29/29 [==============================] - 0s 4ms/step - loss: 9.2624e-04 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9966
#
# Epoch 00094: val_loss did not improve from 0.04364
# Epoch 95/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0655 - val_accuracy: 0.9966
#
# Epoch 00095: val_loss did not improve from 0.04364
# Epoch 96/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9983 - val_loss: 0.0590 - val_accuracy: 0.9966
#
# Epoch 00096: val_loss did not improve from 0.04364
# Epoch 97/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0047 - accuracy: 0.9965 - val_loss: 0.0606 - val_accuracy: 0.9966
#
# Epoch 00097: val_loss did not improve from 0.04364
# Epoch 98/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.0631 - val_accuracy: 0.9966
#
# Epoch 00098: val_loss did not improve from 0.04364
# Epoch 99/100
# 29/29 [==============================] - 0s 5ms/step - loss: 1.7640e-04 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9966
#
# Epoch 00099: val_loss did not improve from 0.04364
# Epoch 100/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0612 - val_accuracy: 0.9966
#
# Epoch 00100: val_loss did not improve from 0.04364
# Training completed in time:  0:00:15.657185

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print('Accuracy is',test_accuracy[1])
# Out:
# Accuracy is 0.9965517520904541

# %%
#Testing Some Test Audio Data


filename="C:/Users/Ankit Kumar/Audio_Data/Audio/Ball_Racket_Stairwell_01016_user.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

#print(mfccs_scaled_features)
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
#print(mfccs_scaled_features)
#print(mfccs_scaled_features.shape)
predicted_label=model.predict_classes(mfccs_scaled_features)
print(predicted_label)
# Out:
# [1]
